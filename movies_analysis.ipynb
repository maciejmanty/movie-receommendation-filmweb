# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Mantyk\Desktop\Data Analysis\Filmweb\Working\PyCharm\Movies')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9185 entries, 0 to 9184
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   polish_title    9185 non-null   object
#  1   original_title  9185 non-null   object
#  2   score           9185 non-null   float64
#  3   year            9185 non-null   int64
#  4   length          9185 non-null   int64
#  5   genre           9184 non-null   object
#  6   director        9169 non-null   object
#  7   country         9184 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 574.2+ KB

# %%
df.shape
# Out:
# (9185, 8)

# %%
df[df.duplicated()]
# Out:
#                  polish_title           original_title  score  year  length  \
# 2209         Tata kontra tata             Daddy's Home    6.2  2015      96
# 2210         M jak morderstwo        Dial M for Murder    7.9  1954     105
# 2211           Myśl jak facet         Think Like a Man    6.7  2012     122
# 2212       Prawdziwe kłamstwa                True Lies    7.1  1994     144
# 2213          Kroniki portowe        The Shipping News    7.3  2001     111
# ...                       ...                      ...    ...   ...     ...
# 9180    De Domeinen Ditvoorst    De Domeinen Ditvoorst    5.0  1992     112
# 9181       Novias impacientes       Novias impacientes    7.0  1967      85
# 9182  Las Mariposas disecadas  Las Mariposas disecadas    4.0  1978     106
# 9183        Los Amantes frios        Los Amantes frios    4.0  1978     114
# 9184        20h17 rue Darling        20h17 rue Darling    7.0  2003     101
#
# ...

# %%
df[df.isna().any(axis=1)]
# Out:
#                                            polish_title  \
# 2581                                            Naprzód
# 3557                                     Superprodukcja
# 4718                Percy Jackson and the Titan's Curse
# 8550                                    Miliardowy okup
# 9050                               The Great Stone Face
# 9054  Hollywood at Your Feet: The Story of the Chine...
# 9057                                              Teatr
# 9080                            Las Mariposas disecadas
# 9093                          Wypracowanie nie na temat
# 9097                                              Teatr
# 9104                                  Muzhskoy razgovor
# 9118                                   Who Stole Santa?
# 9131                                   Who Stole Santa?
# 9158                                  Bells of Rosarita
# 9164                                        The Hit Man
# 9168                                  Bells of Rosarita
# ...

# %%
df = df.drop_duplicates()
df = df.dropna()
df.shape
# Out:
# (8715, 8)

# %%
df.head()
# Out:
#                          polish_title                         original_title  \
# 0                                 300                                    300
# 1             Przerwana lekcja muzyki                      Girl, Interrupted
# 2  Harry Potter i Kamień Filozoficzny  Harry Potter and the Sorcerer's Stone
# 3          Złap mnie, jeśli potrafisz                    Catch Me If You Can
# 4                        Donnie Darko                           Donnie Darko
#
#    score  year  length               genre          director country
# 0    7.5  2006     117  Dramat historyczny       Zack Snyder     USA
# 1    7.9  1999     127        Biograficzny     James Mangold  Niemcy
# 2    7.5  2001     152           Familijny    Chris Columbus     USA
# 3    7.9  2002     141  Komedia kryminalna  Steven Spielberg  Kanada
# 4    7.7  2001     113              Dramat     Richard Kelly     USA

# %%
df.tail()
# Out:
#                 polish_title          original_title  score  year  length  \
# 9161         The Blue Parrot         The Blue Parrot    4.0  1953      69
# 9162             Montecarlo!             Montecarlo!    5.0  2004      80
# 9163  The Dragon Murder Case  The Dragon Murder Case    6.0  1934      68
# 9175                Halvblod                Halvblod    7.0  1913      69
# 9176           Fluchtversuch           Fluchtversuch   10.0  1976      95
#
#          genre                  director          country
# 9161    Dramat  John HarlowgatunekDramat  Wielka Brytania
# 9162   Komedia             Gábor Fischer            Węgry
# 9163  Kryminał      H. Bruce Humberstone              USA
# 9175    Dramat           Victor Sjöström          Szwecja
# 9176    Dramat             Vojtěch Jasný          Austria

# %%
# df.to_excel('Movies_excel.xlsx')
